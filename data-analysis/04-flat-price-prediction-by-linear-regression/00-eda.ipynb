# %%
import pandas as pd

# %%
df = pd.read_csv('data/raw/train.csv')
print(df.shape)
df.head(6)
# Out:
# (206474, 76)
#             city  floor          id        lat        lng  \
# 0     Ставрополь    NaN   COL_65683  45.011356  41.919273
# 1           Омск    NaN  COL_159011  54.984833  73.387344
# 2       Белгород    NaN  COL_205850  50.576805  36.563267
# 3  Большой Исток    NaN  COL_229491  56.714413  60.792454
# 4    Новосибирск    1.0   COL_77283  55.055200  82.895810
# 5     Красноярск    1.0  COL_237766  56.054585  92.923680
#
#    osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                            7                           71
# 1                            4                           40
# 2                            0                            9
# 3                            0                            0
# 4                            0                           25
# 5                            3                           15
#
#    osm_amenity_points_in_0.0075  osm_amenity_points_in_0.01  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206474 entries, 0 to 206473
# Data columns (total 76 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   city                                 206474 non-null  object
#  1   floor                                76209 non-null   float64
#  2   id                                   206474 non-null  object
#  3   lat                                  206474 non-null  float64
#  4   lng                                  206474 non-null  float64
#  5   osm_amenity_points_in_0.001          206474 non-null  int64
#  6   osm_amenity_points_in_0.005          206474 non-null  int64
#  7   osm_amenity_points_in_0.0075         206474 non-null  int64
#  8   osm_amenity_points_in_0.01           206474 non-null  int64
#  9   osm_building_points_in_0.001         206474 non-null  int64
#  10  osm_building_points_in_0.005         206474 non-null  int64
# ...

# %%
df.describe()
# Out:
#               floor            lat            lng  \
# count  76209.000000  206474.000000  206474.000000
# mean       1.856802      54.343090      47.505203
# std        5.416645       4.255719      16.693365
# min       -3.000000      42.651897      19.892178
# 25%        1.000000      53.225391      37.583230
# 50%        1.000000      55.677577      39.676300
# 75%        1.000000      56.296827      55.930234
# max      123.000000      69.492140     151.777000
#
#        osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# count                206474.000000                206474.000000
# mean                      2.686672                    40.283300
# std                       4.180174                    52.692116
# min                       0.000000                     0.000000
# 25%                       0.000000                     7.000000
# 50%                       1.000000                    22.000000
# ...

# %%
for column in df.columns[df.isnull().any()]:
    print(f'- {column} (~{round(100 * df[column].isna().sum() / len(df))}%)')
# Out:
# - floor (~63%)
# - osm_city_nearest_population (~0%)
# - reform_house_population_1000 (~5%)
# - reform_house_population_500 (~10%)
# - reform_mean_floor_count_1000 (~6%)
# - reform_mean_floor_count_500 (~11%)
# - reform_mean_year_building_1000 (~6%)
# - reform_mean_year_building_500 (~11%)
# - street (~1%)

# %%
df[['floor',
    'osm_amenity_points_in_0.005',
    'osm_catering_points_in_0.005',
    'osm_finance_points_in_0.005',
    'osm_culture_points_in_0.005',
    'osm_crossing_points_in_0.005',
    'osm_healthcare_points_in_0.005',
    'osm_historic_points_in_0.005',
    'osm_hotels_points_in_0.005',
    'osm_offices_points_in_0.005',
    'osm_shops_points_in_0.005',
    'osm_subway_closest_dist',
    'osm_city_closest_dist',
    'osm_city_nearest_population',
    'osm_crossing_closest_dist',
    'reform_count_of_houses_500',
    'reform_house_population_500',
    'reform_mean_floor_count_500',
    'reform_mean_year_building_500',
    'total_square',
    'per_square_meter_price',
    ]].hist(bins=100, figsize=(35, 15));

# %%
df.city.value_counts()
# Out:
# Москва                                         41921
# Санкт-Петербург                                13947
# Краснодар                                       9703
# Екатеринбург                                    6258
# Новосибирск                                     4924
#                                                ...
# Урожайное                                          1
# Азнакаевский район, Актюбинский пгт                1
# Балаганск                                          1
# Чебаркульский район, с. Травники                   1
# Пожарский район, с. Светлогорье, Первый мкр        1
# Name: city, Length: 4431, dtype: int64
